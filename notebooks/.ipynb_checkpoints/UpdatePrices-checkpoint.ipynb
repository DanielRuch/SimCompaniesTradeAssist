# %%
#Update Prices
# Dependencies

#API Dependencies
import requests
import json
import datetime
apiTimePath = r"..\resources\lastAPICall.txt"
targetURL = "https://www.simcompanies.com/api/v1/market-ticker/2020-04-15T02:15:53.761Z" #Market data URL

#Database Dependencies
from sqlalchemy import create_engine, Column, Integer, String, Float, update
from sqlalchemy.ext.declarative import declarative_base
Base = declarative_base()

# %%
#Create table structures (grab from DatabaseMaint notebook if out of date)
class Item(Base):
    __tablename__ = 'item'
    id = Column(Integer, primary_key=True)
    price = Column(Float(2))
    name = Column(String(255))
    kind = Column(Integer)
    updtDtTm = Column(String(20))
    
# Creates a connection to our DB
engine = create_engine("sqlite:///../resources/db/db.sqlite")
conn = engine.connect()

# Create a Session Object to Connect to DB
from sqlalchemy.orm import Session
session = Session(bind=engine)

# %%
#Test time of last API call - if less than 6 minutes since last run, don't execute new data call
#Get last time of API call
with open(apiTimePath, 'r+') as apiTimeFile:
    lastApiCallTime = apiTimeFile.readline()

#Convert to datetime format
lastApiCallTime = datetime.datetime.strptime(lastApiCallTime, '%Y-%m-%d %H:%M:%S.%f')

#Compare to current time
curTime = datetime.datetime.now()
timeDiff = (curTime - lastApiCallTime)

#Convert to minutes
minDiff = timeDiff.seconds/60
print(f'Minutes since last refresh: {minDiff:.2f}')
# Out:
# Minutes since last refresh: 49.25

# %%
#Handle API Call
if minDiff > 6:
    marketData = requests.get(targetURL).json()
    print("Grabbed market data successfully")
    curTimeStr = str(datetime.datetime.now())
    with open(apiTimePath, 'w') as apiTimeFile:
        apiTimeFile.write(curTimeStr)
        print("Added new time successfully")
    
else:
    print("Fewer than 6 minutes since last API Call - did not execute API Call")
# Out:
# Grabbed market data successfully
# Added new time successfully

# %%
for i in marketData:
    print(i)
# Out:
# {'kind': 108, 'image': 'images/resources/planks.png', 'price': 9.4, 'is_up': False}
# {'kind': 34, 'image': 'images/resources/chemistry-research.png', 'price': 171.0, 'is_up': False}
# {'kind': 76, 'image': 'images/resources/carbon-composite.png', 'price': 66.5, 'is_up': False}
# {'kind': 53, 'image': 'images/resources/economy-e-car.png', 'price': 3300.0, 'is_up': True}
# {'kind': 79, 'image': 'images/resources/high-grade-e-components.png', 'price': 995.0, 'is_up': True}
# {'kind': 24, 'image': 'images/resources/smart-phones.png', 'price': 575.0, 'is_up': True}
# {'kind': 58, 'image': 'images/resources/automotive-research.png', 'price': 226.0, 'is_up': False}
# {'kind': 28, 'image': 'images/resources/televisions.png', 'price': 850.0, 'is_up': False}
# {'kind': 44, 'image': 'images/resources/sand.png', 'price': 1.17, 'is_up': True}
# {'kind': 21, 'image': 'images/resources/electronic-components.png', 'price': 57.5, 'is_up': False}
# {'kind': 1, 'image': 'images/resources/power.png', 'price': 0.256, 'is_up': True}
# {'kind': 33, 'image': 'images/resources/breeding-research.png', 'price': 188.0, 'is_up': False}
# {'kind': 17, 'image': 'images/resources/chemicals.png', 'price': 14.6, 'is_up': False}
# {'kind': 111, 'image': 'images/resources/construction-units.png', 'price': 2730.0, 'is_up': True}
# {'kind': 55, 'image': 'images/resources/economy-car.png', 'price': 2240.0, 'is_up': True}
# {'kind': 9, 'image': 'images/resources/eggs.png', 'price': 1.05, 'is_up': True}
# {'kind': 86, 'image': 'images/resources/rocket-engine.png', 'price': 13400.0, 'is_up': False}
# {'kind': 2, 'image': 'images/resources/water.png', 'price': 0.307, 'is_up': True}
# {'kind': 26, 'image': 'images/resources/laptops.png', 'price': 1100.0, 'is_up': False}
# {'kind': 27, 'image': 'images/resources/monitors.png', 'price': 535.0, 'is_up': False}
# {'kind': 3, 'image': 'images/resources/apples.png', 'price': 1.89, 'is_up': False}
# {'kind': 102, 'image': 'images/resources/bricks.png', 'price': 2.45, 'is_up': True}
# {'kind': 83, 'image': 'images/resources/rocket-fuel.png', 'price': 43.5, 'is_up': True}
# {'kind': 101, 'image': 'images/resources/reinforced-concrete.png', 'price': 200.0, 'is_up': True}
# {'kind': 112, 'image': 'images/resources/bulldozer.png', 'price': 2100.0, 'is_up': False}
# {'kind': 72, 'image': 'images/resources/sugarcane.png', 'price': 1.0, 'is_up': False}
# {'kind': 10, 'image': 'images/resources/crude-oil.png', 'price': 26.75, 'is_up': True}
# {'kind': 13, 'image': 'images/resources/transport.png', 'price': 0.359, 'is_up': False}
# {'kind': 75, 'image': 'images/resources/carbon-fiber.png', 'price': 6.5, 'is_up': True}
# {'kind': 14, 'image': 'images/resources/minerals.png', 'price': 11.7, 'is_up': False}
# {'kind': 19, 'image': 'images/resources/plastic.png', 'price': 10.9, 'is_up': False}
# {'kind': 57, 'image': 'images/resources/truck.png', 'price': 5300.0, 'is_up': False}
# {'kind': 113, 'image': 'images/resources/materials-research.png', 'price': 238.0, 'is_up': True}
# {'kind': 23, 'image': 'images/resources/displays.png', 'price': 120.0, 'is_up': True}
# {'kind': 56, 'image': 'images/resources/luxury-car.png', 'price': 4000.0, 'is_up': False}
# {'kind': 105, 'image': 'images/resources/limestone.png', 'price': 1.57, 'is_up': False}
# {'kind': 22, 'image': 'images/resources/batteries.png', 'price': 90.5, 'is_up': False}
# {'kind': 103, 'image': 'images/resources/cement.png', 'price': 7.3, 'is_up': False}
# {'kind': 73, 'image': 'images/resources/ethanol.png', 'price': 22.75, 'is_up': True}
# {'kind': 54, 'image': 'images/resources/luxury-e-car.png', 'price': 6250.0, 'is_up': False}
# {'kind': 82, 'image': 'images/resources/attitude-control.png', 'price': 1560.0, 'is_up': False}
# {'kind': 15, 'image': 'images/resources/bauxite.png', 'price': 9.3, 'is_up': True}
# {'kind': 18, 'image': 'images/resources/aluminium.png', 'price': 18.9, 'is_up': False}
# {'kind': 4, 'image': 'images/resources/oranges.png', 'price': 1.8, 'is_up': False}
# {'kind': 66, 'image': 'images/resources/seeds.png', 'price': 0.2, 'is_up': True}
# {'kind': 30, 'image': 'images/resources/energy-research.png', 'price': 308.0, 'is_up': False}
# {'kind': 104, 'image': 'images/resources/clay.png', 'price': 0.77, 'is_up': True}
# {'kind': 88, 'image': 'images/resources/ion-drive.png', 'price': 13700.0, 'is_up': True}
# {'kind': 70, 'image': 'images/resources/gold-watch.png', 'price': 790.0, 'is_up': False}
# {'kind': 46, 'image': 'images/resources/leather.png', 'price': 13.6, 'is_up': False}
# {'kind': 68, 'image': 'images/resources/gold-ore.png', 'price': 33.75, 'is_up': False}
# {'kind': 43, 'image': 'images/resources/steel.png', 'price': 11.9, 'is_up': True}
# {'kind': 106, 'image': 'images/resources/wood.png', 'price': 3.55, 'is_up': False}
# {'kind': 107, 'image': 'images/resources/steel-beams.png', 'price': 22.0, 'is_up': True}
# {'kind': 74, 'image': 'images/resources/methane.png', 'price': 26.5, 'is_up': True}
# {'kind': 52, 'image': 'images/resources/combustion-engine.png', 'price': 640.0, 'is_up': False}
# {'kind': 16, 'image': 'images/resources/silicon.png', 'price': 7.8, 'is_up': False}
# {'kind': 40, 'image': 'images/resources/cotton.png', 'price': 1.14, 'is_up': True}
# {'kind': 41, 'image': 'images/resources/fabric.png', 'price': 3.55, 'is_up': False}
# {'kind': 109, 'image': 'images/resources/windows.png', 'price': 113.0, 'is_up': False}
# {'kind': 98, 'image': 'images/resources/quadcopter.png', 'price': 830.0, 'is_up': False}
# {'kind': 31, 'image': 'images/resources/mining-research.png', 'price': 338.0, 'is_up': False}
# {'kind': 77, 'image': 'images/resources/fuselage.png', 'price': 2990.0, 'is_up': True}
# {'kind': 60, 'image': 'images/resources/underwear.png', 'price': 4.3, 'is_up': True}
# {'kind': 50, 'image': 'images/resources/car-interior.png', 'price': 320.0, 'is_up': True}
# {'kind': 49, 'image': 'images/resources/luxury-car-interior.png', 'price': 880.0, 'is_up': False}
# {'kind': 29, 'image': 'images/resources/plant-research.png', 'price': 167.0, 'is_up': False}
# {'kind': 85, 'image': 'images/resources/solid-rocket.png', 'price': 8150.0, 'is_up': True}
# {'kind': 8, 'image': 'images/resources/sausages.png', 'price': 3.3, 'is_up': False}
# {'kind': 20, 'image': 'images/resources/processors.png', 'price': 123.0, 'is_up': True}
# {'kind': 12, 'image': 'images/resources/diesel.png', 'price': 40.0, 'is_up': False}
# {'kind': 48, 'image': 'images/resources/electric-motor.png', 'price': 224.0, 'is_up': True}
# {'kind': 6, 'image': 'images/resources/grain.png', 'price': 0.55, 'is_up': True}
# {'kind': 11, 'image': 'images/resources/petrol.png', 'price': 41.75, 'is_up': False}
# {'kind': 32, 'image': 'images/resources/electronics-research.png', 'price': 414.0, 'is_up': False}
# {'kind': 62, 'image': 'images/resources/dress.png', 'price': 17.0, 'is_up': False}
# {'kind': 59, 'image': 'images/resources/fashion-research.png', 'price': 110.0, 'is_up': True}
# {'kind': 51, 'image': 'images/resources/car-body.png', 'price': 740.0, 'is_up': True}
# {'kind': 69, 'image': 'images/resources/golden-bars.png', 'price': 6850.0, 'is_up': True}
# {'kind': 5, 'image': 'images/resources/grapes.png', 'price': 2.2, 'is_up': False}
# {'kind': 42, 'image': 'images/resources/iron-ore.png', 'price': 4.85, 'is_up': True}
# {'kind': 45, 'image': 'images/resources/glass.png', 'price': 13.2, 'is_up': False}
# {'kind': 35, 'image': 'images/resources/software.png', 'price': 160.0, 'is_up': False}
# {'kind': 7, 'image': 'images/resources/steak.png', 'price': 11.5, 'is_up': False}
# {'kind': 84, 'image': 'images/resources/fuel-tank.png', 'price': 11700.0, 'is_up': True}
# {'kind': 25, 'image': 'images/resources/tablets.png', 'price': 725.0, 'is_up': True}
# {'kind': 47, 'image': 'images/resources/on-board-computer.png', 'price': 462.0, 'is_up': False}
# {'kind': 78, 'image': 'images/resources/wing.png', 'price': 2120.0, 'is_up': False}
# {'kind': 100, 'image': 'images/resources/aero-research.png', 'price': 348.0, 'is_up': True}
# {'kind': 110, 'image': 'images/resources/tools.png', 'price': 196.0, 'is_up': True}
# {'kind': 71, 'image': 'images/resources/necklace.png', 'price': 1500.0, 'is_up': True}
# {'kind': 80, 'image': 'images/resources/flight-computer.png', 'price': 5625.0, 'is_up': False}
# {'kind': 81, 'image': 'images/resources/cockpit.png', 'price': 5725.0, 'is_up': True}
# {'kind': 89, 'image': 'images/resources/jet-engine.png', 'price': 5350.0, 'is_up': False}
# {'kind': 65, 'image': 'images/resources/sneakers.png', 'price': 12.5, 'is_up': True}
# {'kind': 63, 'image': 'images/resources/simmi-shoes.png', 'price': 18.4, 'is_up': False}
# {'kind': 61, 'image': 'images/resources/gloves.png', 'price': 10.7, 'is_up': False}
# {'kind': 64, 'image': 'images/resources/handbags.png', 'price': 23.75, 'is_up': False}
# {'kind': 67, 'image': 'images/resources/xmas-crackers.png', 'price': 'sold out', 'is_up': True}
# {'kind': 87, 'image': 'images/resources/heat-shield.png', 'price': 458.0, 'is_up': True}

# %%
# Loop through market data
i = 0
for mktItem in marketData:
    # Extract current item info
    #Extract name from image string
    strTemp = str(mktItem['image']) #image string
    strTemp = strTemp.split('/') #split based on the / character to separate path
    strTemp = strTemp[2].split('.') #then split based on . to separate name from ext
    
    newName = strTemp[0] #0 index now holds our item name
    if mktItem['price'] != "sold out": #Handle items with no market orders - returns "sold out"
        newPrice = float(mktItem['price'])
    else:
        newPrice = 0.00
    newKind = int(mktItem['kind'])
    newUpdtDtTm = str(datetime.datetime.now())
    
    #Search for kind in table
    exists = session.query(Item.id).filter_by(kind=newKind).scalar() is not None
    
    if exists == False: # and i < 5: #Item doesn't currently exist in table
        
        newItem = Item(name=newName, price=newPrice, kind=newKind, updtDtTm=newUpdtDtTm)
        session.add(newItem)
        #Commit (yikes)
        session.commit()
        print(f'{newName} added successfully')
        
    else:
        #Get old data
        oldItem = session.query(Item).filter_by(kind=newKind).first()
        oldPrice = oldItem.price #Save old price for debugging
        oldItem.price = newPrice
        oldItem.updtDtTm = newUpdtDtTm
        session.dirty
        session.commit()
# Updated 2020-07-14 19:30:41.031275
# sneakers updated successfully, old 12.5 -> new 12.5
# Updated 2020-07-14 19:30:41.051221
# simmi-shoes updated successfully, old 18.4 -> new 18.4
# Updated 2020-07-14 19:30:41.075157
# gloves updated successfully, old 10.7 -> new 10.7
# Updated 2020-07-14 19:30:41.101091
# handbags updated successfully, old 23.75 -> new 23.75
# Updated 2020-07-14 19:30:41.125024
# xmas-crackers updated successfully, old 0.0 -> new 0.0
# Updated 2020-07-14 19:30:41.148960
# heat-shield updated successfully, old 458.0 -> new 458.0
# Updated 2020-07-14 19:30:41.171901

# %%
#Test our new data
items = session.query(Item)

for item in items:
    print(f'{item.name} price {item.price}')
# Out:
# xmas-crackers price 29.5
# necklace price 1500.0
# monitors price 545.0
# silicon price 7.6
# power price 0.25
# gloves price 10.3
# sneakers price 12.5
# electronics-research price 410.0
# displays price 119.0
# apples price 1.9
# leather price 13.0
# plant-research price 163.0
# construction-units price 2690.0
# water price 0.308
# crude-oil price 27.75
# automotive-research price 236.0
# gold-ore price 33.75
# plastic price 10.9
# transport price 0.359
# steel price 11.7
# batteries price 88.0
# underwear price 4.3
# carbon-fiber price 6.7
# grain price 0.54
# bauxite price 9.2
# diesel price 40.5
# methane price 28.25
# aluminium price 18.5
# eggs price 1.03
# oranges price 1.79
# reinforced-concrete price 204.0
# software price 164.0
# seeds price 0.204
# combustion-engine price 610.0
# ethanol price 23.0
# minerals price 11.7
# sand price 1.18
# tools price 202.0
# steak price 11.3
# planks price 9.1
# rocket-fuel price 44.25
# sausages price 3.2
# bricks price 2.45
# economy-e-car price 3400.0
# grapes price 2.0
# truck price 5675.0
# materials-research price 230.0
# energy-research price 310.0
# sugarcane price 1.35
# wood price 3.25
# golden-bars price 6950.0
# iron-ore price 4.9
# chemicals price 14.7
# ion-drive price 13000.0
# high-grade-e-components price 970.0
# chemistry-research price 170.0
# electric-motor price 222.0
# on-board-computer price 452.0
# electronic-components price 55.0
# mining-research price 352.0
# aero-research price 346.0
# windows price 110.0
# car-body price 720.0
# processors price 120.0
# carbon-composite price 64.5
# fashion-research price 109.0
# tablets price 735.0
# limestone price 1.54
# fabric price 3.5
# steel-beams price 19.9
# glass price 12.5
# quadcopter price 840.0
# fuselage price 2890.0
# flight-computer price 5425.0
# petrol price 40.25
# jet-engine price 5500.0
# fuel-tank price 11800.0
# breeding-research price 200.0
# cotton price 1.14
# bulldozer price 2140.0
# luxury-car price 4350.0
# cement price 7.0
# clay price 0.75
# cockpit price 5875.0
# solid-rocket price 8175.0
# simmi-shoes price 18.9
# luxury-car-interior price 825.0
# handbags price 25.75
# smart-phones price 590.0
# gold-watch price 805.0
# attitude-control price 1540.0
# rocket-engine price 12700.0
# dress price 17.6
# car-interior price 318.0
# laptops price 1160.0
# wing price 2230.0
# economy-car price 2230.0
# heat-shield price 450.0
# televisions price 890.0
# luxury-e-car price 6300.0
