# %%
#Scripts to maintain database

# %%
# Dependencies
# ----------------------------------
from sqlalchemy import create_engine, func # Imports the method used for connecting to DBs
from sqlalchemy.ext.declarative import declarative_base # Imports the methods needed to abstract classes into tables
from sqlalchemy import Column, Integer, String, Float, ForeignKey # Allow us to declare column types
from sqlalchemy.orm import relationship
import csv
import pandas as pd #drastically eases 

compTemplPath = "../resources/templates/componentTemplate.csv"

# %%
#CREATE TABLES

# #CREATE TABLE TEMPLATE
# class Item(Base):
#     __tablename__ = 'item'
#     id = Column(Integer, primary_key=True)
#     float = Column(Float(2))
#     string = Column(String(255))
#     int = Column(Integer)

# # Create (if not already in existence) the tables associated with our classes.
# Base.metadata.create_all(engine)

# Sets an object to utilize the default declarative base in SQL Alchemy
Base = declarative_base()


# Creates Classes which will serve as the anchor points for our Tables
class Item(Base):
    __tablename__ = 'item'
    id = Column(Integer, primary_key=True) #Change this to itemId
    price = Column(Float(2))
    name = Column(String(255))
    kind = Column(Integer)
    updtDtTm = Column(String(20))
    #baseQtyPerHr = Column(Float(2)) #Need to add production per hour per level
    
class compReltn(Base):
    __tablename__ = 'component_reltn'
    comp_reltn_id = Column(Integer, primary_key=True)
    parent_item_id = Column(Integer, ForeignKey(Item.id))
    comp_item_id = Column(Integer, ForeignKey(Item.id))
    component_qty = Column(Integer)

parentItem = relationship('Item', foreign_keys='compReltn.parent_item_id') #Parent Id Relation
compItem = relationship('Item', foreign_keys='compReltn.comp_item_id') #Component Id Relation

# %%
# Create Database Connection
# ----------------------------------
# Creates a connection to our DB
engine = create_engine("sqlite:///../resources/db/db.sqlite")
conn = engine.connect()

# %%
# Create a "Metadata" Layer That Abstracts our SQL Database
# ----------------------------------
# Create (if not already in existence) the tables associated with our classes.
Base.metadata.create_all(engine)

# Use this to clear out the db
# ----------------------------------
#Base.metadata.drop_all(engine)

# %%
# Create a Session Object to Connect to DB
# ----------------------------------
from sqlalchemy.orm import Session
session = Session(bind=engine)

# %%
#Import component template data
# Template contains data of each item's components, and their respective quantities
# NOTE: This could place heavy loads on SQL, as it's making a BUNCH of micro calls. Might give this a bit
#    to run and be mindful of potential slowness elsewhere

#Read in CSV file, append to arroy
newRow = []
templateData = []

with open(compTemplPath, newline='') as csvfile:
    csvfile.seek(0)
    reader = csv.reader(csvfile, delimiter='\t')
    for row in reader: #Loop through csv file
        for col in row: #Each column within row
            newRow.append(col) #Append column
        templateData.append(newRow) #When done with row, append to data array
        newRow = [] #Clear out row list

#For each item, we must do the following:
    # DONE - Look up parent item (first item listed) based on name
        # If not found, skip the entire row. We can't go any further with this item. Log this out
    # DONE - Look up component item - similar to above. Need to get this, otherwise skip addition
    # Finally, we need to check if this relationship between parent and component already exists.
        # If no, proceed to add
        # If yes, check if qty matches - if so, skip; if no, update
    
for row in templateData:
    parentName = row[0].upper()
    compName = row[1].upper()
    compQty = float(row[2])
    #print(parentName)
    
    #Search for parent item in table
    exists = session.query(Item).filter(Item.name.ilike(parentName)).scalar() is not None
    
    if exists == False:
        continue #Skip
    else: 
        # Do stuff
        parentData = session.query(Item).filter(Item.name.ilike(parentName)).first()
        parentId = parentData.id
        #print(parentId)
        
    exists = session.query(Item).filter(Item.name.ilike(compName)).scalar() is not None
    
    #Look up component item
    if exists == False:
        continue #Skip
    else:
        # Do component stuff
        compData = session.query(Item).filter(Item.name.ilike(compName)).first()
        compId = compData.id
    
    #Check if both exist in comp reltn already
    exists = session.query(compReltn).filter(compReltn.parent_item_id == parentId, compReltn.comp_item_id == compId).scalar() is not None
    
    if exists == False:
        #Do stuff here
        #INSERT
        newReltn = compReltn(parent_item_id = parentId, comp_item_id = compId, component_qty = compQty)
        session.add(newReltn)
        session.commit()
    else:
        #Get Qty
        existingData = session.query(compReltn).filter(compReltn.parent_item_id == parentId, compReltn.comp_item_id == compId).first()
        existingQty = existingData.component_qty
    #print(exists)
    print(f'parent: {parentId} {parentName} | component {compId} {compName} | Qty {compQty}')
# Out:
# parent: 33 SEEDS | component 14 WATER | Qty 0.1
# parent: 10 APPLES | component 14 WATER | Qty 3.0
# parent: 30 ORANGES | component 14 WATER | Qty 3.0
# parent: 45 GRAPES | component 14 WATER | Qty 4.0
# parent: 24 GRAIN | component 14 WATER | Qty 0.5
# parent: 49 SUGARCANE | component 14 WATER | Qty 3.0
# parent: 79 COTTON | component 14 WATER | Qty 1.0
# parent: 50 WOOD | component 14 WATER | Qty 4.0
# parent: 10 APPLES | component 33 SEEDS | Qty 1.0
# parent: 30 ORANGES | component 33 SEEDS | Qty 1.0
# parent: 45 GRAPES | component 33 SEEDS | Qty 1.0
# parent: 24 GRAIN | component 33 SEEDS | Qty 1.0
# parent: 49 SUGARCANE | component 33 SEEDS | Qty 1.0
# parent: 79 COTTON | component 33 SEEDS | Qty 1.0
# parent: 50 WOOD | component 33 SEEDS | Qty 1.0
# parent: 33 SEEDS | component 19 TRANSPORT | Qty 0.1
# parent: 10 APPLES | component 19 TRANSPORT | Qty 1.0
# parent: 30 ORANGES | component 19 TRANSPORT | Qty 1.0
# parent: 45 GRAPES | component 19 TRANSPORT | Qty 1.0
# parent: 24 GRAIN | component 19 TRANSPORT | Qty 0.1
# parent: 49 SUGARCANE | component 19 TRANSPORT | Qty 0.1
# parent: 79 COTTON | component 19 TRANSPORT | Qty 0.5
# parent: 50 WOOD | component 19 TRANSPORT | Qty 1.0
# parent: 39 STEAK | component 14 WATER | Qty 8.0
# parent: 42 SAUSAGES | component 14 WATER | Qty 3.0
# parent: 29 EGGS | component 14 WATER | Qty 0.4
# parent: 11 LEATHER | component 14 WATER | Qty 5.0
# parent: 39 STEAK | component 24 GRAIN | Qty 10.0
# parent: 42 SAUSAGES | component 24 GRAIN | Qty 2.0
# parent: 29 EGGS | component 24 GRAIN | Qty 0.5
# parent: 11 LEATHER | component 24 GRAIN | Qty 10.0
# parent: 39 STEAK | component 19 TRANSPORT | Qty 1.0
# parent: 42 SAUSAGES | component 19 TRANSPORT | Qty 0.1
# parent: 29 EGGS | component 19 TRANSPORT | Qty 0.1
# parent: 11 LEATHER | component 19 TRANSPORT | Qty 1.0
# parent: 37 SAND | component 5 POWER | Qty 2.0
# parent: 83 CLAY | component 5 POWER | Qty 1.0
# parent: 68 LIMESTONE | component 5 POWER | Qty 2.0
# parent: 37 SAND | component 19 TRANSPORT | Qty 1.0
# parent: 83 CLAY | component 19 TRANSPORT | Qty 1.0
# parent: 68 LIMESTONE | component 19 TRANSPORT | Qty 1.0
# parent: 31 REINFORCED-CONCRETE | component 82 CEMENT | Qty 15.0
# parent: 31 REINFORCED-CONCRETE | component 37 SAND | Qty 20.0
# parent: 31 REINFORCED-CONCRETE | component 14 WATER | Qty 20.0
# parent: 31 REINFORCED-CONCRETE | component 20 STEEL | Qty 5.0
# parent: 31 REINFORCED-CONCRETE | component 19 TRANSPORT | Qty 10.0
# parent: 43 BRICKS | component 83 CLAY | Qty 0.5
# parent: 82 CEMENT | component 68 LIMESTONE | Qty 3.0
# parent: 43 BRICKS | component 19 TRANSPORT | Qty 1.0
# parent: 82 CEMENT | component 19 TRANSPORT | Qty 1.0
# parent: 14 WATER | component 5 POWER | Qty 0.2
# parent: 15 CRUDE-OIL | component 5 POWER | Qty 25.0
# parent: 27 METHANE | component 5 POWER | Qty 20.0
# parent: 15 CRUDE-OIL | component 19 TRANSPORT | Qty 1.0
# parent: 27 METHANE | component 19 TRANSPORT | Qty 1.0
# parent: 75 PETROL | component 5 POWER | Qty 15.0
# parent: 26 DIESEL | component 5 POWER | Qty 15.0
# parent: 18 PLASTIC | component 5 POWER | Qty 5.0
# parent: 23 CARBON-FIBER | component 5 POWER | Qty 0.5
# parent: 41 ROCKET-FUEL | component 5 POWER | Qty 5.0
# parent: 75 PETROL | component 15 CRUDE-OIL | Qty 0.75
# parent: 26 DIESEL | component 15 CRUDE-OIL | Qty 0.75
# parent: 18 PLASTIC | component 15 CRUDE-OIL | Qty 0.2
# parent: 23 CARBON-FIBER | component 15 CRUDE-OIL | Qty 0.1
# parent: 41 ROCKET-FUEL | component 27 METHANE | Qty 1.0
# parent: 75 PETROL | component 19 TRANSPORT | Qty 1.0
# parent: 26 DIESEL | component 19 TRANSPORT | Qty 1.0
# parent: 18 PLASTIC | component 19 TRANSPORT | Qty 1.0
# parent: 23 CARBON-FIBER | component 19 TRANSPORT | Qty 0.1
# parent: 41 ROCKET-FUEL | component 19 TRANSPORT | Qty 1.0
# parent: 75 PETROL | component 35 ETHANOL | Qty 0.25
# parent: 26 DIESEL | component 35 ETHANOL | Qty 0.25
# parent: 19 TRANSPORT | component 5 POWER | Qty 0.01
# parent: 19 TRANSPORT | component 26 DIESEL | Qty 0.005
# parent: 35 ETHANOL | component 5 POWER | Qty 20.0
# parent: 35 ETHANOL | component 49 SUGARCANE | Qty 10.0
# parent: 35 ETHANOL | component 19 TRANSPORT | Qty 1.0
# parent: 36 MINERALS | component 5 POWER | Qty 20.0
# parent: 25 BAUXITE | component 5 POWER | Qty 14.0
# parent: 17 GOLD-ORE | component 5 POWER | Qty 80.0
# parent: 52 IRON-ORE | component 5 POWER | Qty 7.0
# parent: 36 MINERALS | component 14 WATER | Qty 1.0
# parent: 25 BAUXITE | component 14 WATER | Qty 0.5
# parent: 17 GOLD-ORE | component 14 WATER | Qty 2.0
# parent: 52 IRON-ORE | component 14 WATER | Qty 0.5
# parent: 36 MINERALS | component 19 TRANSPORT | Qty 1.0
# parent: 25 BAUXITE | component 19 TRANSPORT | Qty 1.0
# parent: 17 GOLD-ORE | component 19 TRANSPORT | Qty 10.0
# parent: 52 IRON-ORE | component 19 TRANSPORT | Qty 1.0
# parent: 4 SILICON | component 5 POWER | Qty 3.0
# parent: 53 CHEMICALS | component 5 POWER | Qty 0.2
# parent: 28 ALUMINIUM | component 5 POWER | Qty 15.0
# parent: 51 GOLDEN-BARS | component 5 POWER | Qty 40.0
# parent: 20 STEEL | component 5 POWER | Qty 5.0
# parent: 71 GLASS | component 5 POWER | Qty 2.0
# parent: 65 CARBON-COMPOSITE | component 23 CARBON-FIBER | Qty 8.0
# parent: 4 SILICON | component 19 TRANSPORT | Qty 1.0
# parent: 53 CHEMICALS | component 19 TRANSPORT | Qty 1.0
# parent: 28 ALUMINIUM | component 19 TRANSPORT | Qty 1.0
# parent: 51 GOLDEN-BARS | component 19 TRANSPORT | Qty 1000.0
# parent: 20 STEEL | component 19 TRANSPORT | Qty 1.0
# parent: 71 GLASS | component 19 TRANSPORT | Qty 1.0
# parent: 65 CARBON-COMPOSITE | component 19 TRANSPORT | Qty 1.0
# parent: 4 SILICON | component 37 SAND | Qty 2.0
# parent: 53 CHEMICALS | component 36 MINERALS | Qty 1.0
# parent: 28 ALUMINIUM | component 25 BAUXITE | Qty 1.0
# parent: 51 GOLDEN-BARS | component 17 GOLD-ORE | Qty 200.0
# parent: 20 STEEL | component 52 IRON-ORE | Qty 1.0
# parent: 71 GLASS | component 4 SILICON | Qty 1.0
# parent: 20 STEEL | component 53 CHEMICALS | Qty 0.1
# parent: 64 PROCESSORS | component 4 SILICON | Qty 4.0
# parent: 59 ELECTRONIC-COMPONENTS | component 4 SILICON | Qty 3.0
# parent: 21 BATTERIES | component 53 CHEMICALS | Qty 4.0
# parent: 9 DISPLAYS | component 4 SILICON | Qty 5.0
# parent: 89 SMART-PHONES | component 64 PROCESSORS | Qty 2.0
# parent: 67 TABLETS | component 64 PROCESSORS | Qty 2.0
# parent: 95 LAPTOPS | component 64 PROCESSORS | Qty 4.0
# parent: 3 MONITORS | component 59 ELECTRONIC-COMPONENTS | Qty 2.0
# parent: 99 TELEVISIONS | component 64 PROCESSORS | Qty 1.0
# parent: 58 ON-BOARD-COMPUTER | component 64 PROCESSORS | Qty 2.0
# parent: 55 HIGH-GRADE-E-COMPONENTS | component 4 SILICON | Qty 4.0
# parent: 64 PROCESSORS | component 19 TRANSPORT | Qty 1.0
# parent: 59 ELECTRONIC-COMPONENTS | component 19 TRANSPORT | Qty 1.0
# parent: 21 BATTERIES | component 19 TRANSPORT | Qty 1.0
# parent: 9 DISPLAYS | component 19 TRANSPORT | Qty 1.0
# parent: 89 SMART-PHONES | component 19 TRANSPORT | Qty 2.0
# parent: 67 TABLETS | component 19 TRANSPORT | Qty 2.0
# parent: 95 LAPTOPS | component 19 TRANSPORT | Qty 2.0
# parent: 3 MONITORS | component 19 TRANSPORT | Qty 2.0
# parent: 99 TELEVISIONS | component 19 TRANSPORT | Qty 2.0
# parent: 58 ON-BOARD-COMPUTER | component 19 TRANSPORT | Qty 1.0
# parent: 55 HIGH-GRADE-E-COMPONENTS | component 19 TRANSPORT | Qty 1.0
# parent: 64 PROCESSORS | component 53 CHEMICALS | Qty 1.0
# parent: 59 ELECTRONIC-COMPONENTS | component 53 CHEMICALS | Qty 1.0
# parent: 9 DISPLAYS | component 53 CHEMICALS | Qty 4.0
# parent: 89 SMART-PHONES | component 59 ELECTRONIC-COMPONENTS | Qty 1.0
# parent: 67 TABLETS | component 59 ELECTRONIC-COMPONENTS | Qty 1.0
# parent: 95 LAPTOPS | component 59 ELECTRONIC-COMPONENTS | Qty 3.0
# parent: 3 MONITORS | component 9 DISPLAYS | Qty 3.0
# parent: 99 TELEVISIONS | component 59 ELECTRONIC-COMPONENTS | Qty 4.0
# parent: 58 ON-BOARD-COMPUTER | component 59 ELECTRONIC-COMPONENTS | Qty 3.0
# parent: 55 HIGH-GRADE-E-COMPONENTS | component 53 CHEMICALS | Qty 3.0
# parent: 55 HIGH-GRADE-E-COMPONENTS | component 51 GOLDEN-BARS | Qty 0.0625
# parent: 89 SMART-PHONES | component 21 BATTERIES | Qty 1.0
# parent: 67 TABLETS | component 21 BATTERIES | Qty 1.0
# parent: 95 LAPTOPS | component 21 BATTERIES | Qty 2.0
# parent: 3 MONITORS | component 18 PLASTIC | Qty 3.0
# parent: 99 TELEVISIONS | component 9 DISPLAYS | Qty 4.0
# parent: 89 SMART-PHONES | component 9 DISPLAYS | Qty 1.0
# parent: 67 TABLETS | component 9 DISPLAYS | Qty 2.0
# parent: 95 LAPTOPS | component 9 DISPLAYS | Qty 2.0
# parent: 99 TELEVISIONS | component 18 PLASTIC | Qty 5.0
# parent: 89 SMART-PHONES | component 28 ALUMINIUM | Qty 2.0
# parent: 67 TABLETS | component 28 ALUMINIUM | Qty 3.0
# parent: 95 LAPTOPS | component 18 PLASTIC | Qty 3.0
# parent: 69 FABRIC | component 79 COTTON | Qty 2.0
# parent: 22 UNDERWEAR | component 69 FABRIC | Qty 1.0
# parent: 6 GLOVES | component 69 FABRIC | Qty 0.5
# parent: 93 DRESS | component 69 FABRIC | Qty 3.0
# parent: 86 SIMMI-SHOES | component 11 LEATHER | Qty 1.0
# parent: 88 HANDBAGS | component 11 LEATHER | Qty 1.5
# parent: 7 SNEAKERS | component 18 PLASTIC | Qty 1.0
# parent: 90 GOLD-WATCH | component 51 GOLDEN-BARS | Qty 0.1
# parent: 2 NECKLACE | component 51 GOLDEN-BARS | Qty 0.25
# parent: 69 FABRIC | component 19 TRANSPORT | Qty 0.5
# parent: 22 UNDERWEAR | component 19 TRANSPORT | Qty 1.0
# parent: 6 GLOVES | component 19 TRANSPORT | Qty 1.0
# parent: 93 DRESS | component 19 TRANSPORT | Qty 1.0
# parent: 86 SIMMI-SHOES | component 19 TRANSPORT | Qty 1.0
# parent: 88 HANDBAGS | component 19 TRANSPORT | Qty 1.0
# parent: 7 SNEAKERS | component 19 TRANSPORT | Qty 1.0
# parent: 90 GOLD-WATCH | component 19 TRANSPORT | Qty 1.0
# parent: 2 NECKLACE | component 19 TRANSPORT | Qty 1.0
# parent: 69 FABRIC | component 5 POWER | Qty 1.0
# parent: 6 GLOVES | component 11 LEATHER | Qty 0.5
# parent: 93 DRESS | component 18 PLASTIC | Qty 0.5
# parent: 86 SIMMI-SHOES | component 18 PLASTIC | Qty 0.2
# parent: 90 GOLD-WATCH | component 59 ELECTRONIC-COMPONENTS | Qty 2.0
# parent: 90 GOLD-WATCH | component 71 GLASS | Qty 0.5
# parent: 87 LUXURY-CAR-INTERIOR | component 9 DISPLAYS | Qty 6.0
# parent: 94 CAR-INTERIOR | component 9 DISPLAYS | Qty 2.0
# parent: 63 CAR-BODY | component 28 ALUMINIUM | Qty 30.0
# parent: 44 ECONOMY-E-CAR | component 57 ELECTRIC-MOTOR | Qty 2.0
# parent: 100 LUXURY-E-CAR | component 57 ELECTRIC-MOTOR | Qty 4.0
# parent: 97 ECONOMY-CAR | component 34 COMBUSTION-ENGINE | Qty 1.0
# parent: 81 LUXURY-CAR | component 34 COMBUSTION-ENGINE | Qty 2.0
# parent: 46 TRUCK | component 34 COMBUSTION-ENGINE | Qty 6.0
# parent: 80 BULLDOZER | component 20 STEEL | Qty 4.0
# parent: 87 LUXURY-CAR-INTERIOR | component 19 TRANSPORT | Qty 2.0
# parent: 94 CAR-INTERIOR | component 19 TRANSPORT | Qty 2.0
# parent: 63 CAR-BODY | component 19 TRANSPORT | Qty 2.0
# parent: 44 ECONOMY-E-CAR | component 19 TRANSPORT | Qty 5.0
# parent: 100 LUXURY-E-CAR | component 19 TRANSPORT | Qty 5.0
# parent: 97 ECONOMY-CAR | component 19 TRANSPORT | Qty 5.0
# parent: 81 LUXURY-CAR | component 19 TRANSPORT | Qty 5.0
# parent: 46 TRUCK | component 19 TRANSPORT | Qty 5.0
# parent: 80 BULLDOZER | component 19 TRANSPORT | Qty 5.0
# parent: 87 LUXURY-CAR-INTERIOR | component 28 ALUMINIUM | Qty 2.0
# parent: 94 CAR-INTERIOR | component 18 PLASTIC | Qty 2.0
# parent: 63 CAR-BODY | component 71 GLASS | Qty 5.0
# parent: 44 ECONOMY-E-CAR | component 94 CAR-INTERIOR | Qty 1.0
# parent: 100 LUXURY-E-CAR | component 87 LUXURY-CAR-INTERIOR | Qty 1.0
# parent: 97 ECONOMY-CAR | component 94 CAR-INTERIOR | Qty 1.0
# parent: 81 LUXURY-CAR | component 87 LUXURY-CAR-INTERIOR | Qty 1.0
# parent: 46 TRUCK | component 94 CAR-INTERIOR | Qty 1.0
# parent: 80 BULLDOZER | component 63 CAR-BODY | Qty 1.0
# parent: 87 LUXURY-CAR-INTERIOR | component 11 LEATHER | Qty 5.0
# parent: 94 CAR-INTERIOR | component 69 FABRIC | Qty 5.0
# parent: 63 CAR-BODY | component 20 STEEL | Qty 5.0
# parent: 44 ECONOMY-E-CAR | component 63 CAR-BODY | Qty 1.0
# parent: 100 LUXURY-E-CAR | component 63 CAR-BODY | Qty 1.0
# parent: 97 ECONOMY-CAR | component 63 CAR-BODY | Qty 1.0
# parent: 81 LUXURY-CAR | component 63 CAR-BODY | Qty 1.0
# parent: 46 TRUCK | component 63 CAR-BODY | Qty 1.0
# parent: 80 BULLDOZER | component 34 COMBUSTION-ENGINE | Qty 2.0
# parent: 44 ECONOMY-E-CAR | component 21 BATTERIES | Qty 15.0
# parent: 100 LUXURY-E-CAR | component 21 BATTERIES | Qty 30.0
# parent: 97 ECONOMY-CAR | component 58 ON-BOARD-COMPUTER | Qty 1.0
# parent: 81 LUXURY-CAR | component 58 ON-BOARD-COMPUTER | Qty 2.0
# parent: 46 TRUCK | component 20 STEEL | Qty 10.0
# parent: 44 ECONOMY-E-CAR | component 58 ON-BOARD-COMPUTER | Qty 1.0
# parent: 100 LUXURY-E-CAR | component 58 ON-BOARD-COMPUTER | Qty 2.0
# parent: 46 TRUCK | component 58 ON-BOARD-COMPUTER | Qty 1.0
# parent: 57 ELECTRIC-MOTOR | component 20 STEEL | Qty 2.0
# parent: 34 COMBUSTION-ENGINE | component 20 STEEL | Qty 6.0
# parent: 85 SOLID-ROCKET | component 28 ALUMINIUM | Qty 30.0
# parent: 92 ROCKET-ENGINE | component 20 STEEL | Qty 20.0
# parent: 54 ION-DRIVE | component 55 HIGH-GRADE-E-COMPONENTS | Qty 8.0
# parent: 76 JET-ENGINE | component 55 HIGH-GRADE-E-COMPONENTS | Qty 4.0
# parent: 57 ELECTRIC-MOTOR | component 19 TRANSPORT | Qty 2.0
# parent: 34 COMBUSTION-ENGINE | component 19 TRANSPORT | Qty 2.0
# parent: 85 SOLID-ROCKET | component 19 TRANSPORT | Qty 1.0
# parent: 92 ROCKET-ENGINE | component 19 TRANSPORT | Qty 1.0
# parent: 54 ION-DRIVE | component 19 TRANSPORT | Qty 1.0
# parent: 76 JET-ENGINE | component 19 TRANSPORT | Qty 1.0
# parent: 57 ELECTRIC-MOTOR | component 59 ELECTRONIC-COMPONENTS | Qty 3.0
# parent: 34 COMBUSTION-ENGINE | component 53 CHEMICALS | Qty 5.0
# parent: 85 SOLID-ROCKET | component 41 ROCKET-FUEL | Qty 100.0
# parent: 92 ROCKET-ENGINE | component 55 HIGH-GRADE-E-COMPONENTS | Qty 8.0
# parent: 54 ION-DRIVE | component 21 BATTERIES | Qty 30.0
# parent: 76 JET-ENGINE | component 28 ALUMINIUM | Qty 5.0
# parent: 34 COMBUSTION-ENGINE | component 59 ELECTRONIC-COMPONENTS | Qty 5.0
# parent: 85 SOLID-ROCKET | component 53 CHEMICALS | Qty 50.0
# parent: 92 ROCKET-ENGINE | component 28 ALUMINIUM | Qty 10.0
# parent: 54 ION-DRIVE | component 53 CHEMICALS | Qty 15.0
# parent: 73 FUSELAGE | component 65 CARBON-COMPOSITE | Qty 40.0
# parent: 96 WING | component 65 CARBON-COMPOSITE | Qty 30.0
# parent: 77 FUEL-TANK | component 28 ALUMINIUM | Qty 50.0
# parent: 98 HEAT-SHIELD | component 20 STEEL | Qty 20.0
# parent: 73 FUSELAGE | component 19 TRANSPORT | Qty 2.0
# parent: 96 WING | component 19 TRANSPORT | Qty 2.0
# parent: 77 FUEL-TANK | component 19 TRANSPORT | Qty 1.0
# parent: 98 HEAT-SHIELD | component 19 TRANSPORT | Qty 1.0
# parent: 96 WING | component 28 ALUMINIUM | Qty 5.0
# parent: 77 FUEL-TANK | component 41 ROCKET-FUEL | Qty 250.0
# parent: 98 HEAT-SHIELD | component 4 SILICON | Qty 30.0
# parent: 74 FLIGHT-COMPUTER | component 55 HIGH-GRADE-E-COMPONENTS | Qty 4.0
# parent: 84 COCKPIT | component 55 HIGH-GRADE-E-COMPONENTS | Qty 4.0
# parent: 91 ATTITUDE-CONTROL | component 20 STEEL | Qty 3.0
# parent: 72 QUADCOPTER | component 58 ON-BOARD-COMPUTER | Qty 1.0
# parent: 74 FLIGHT-COMPUTER | component 19 TRANSPORT | Qty 1.0
# parent: 84 COCKPIT | component 19 TRANSPORT | Qty 1.0
# parent: 91 ATTITUDE-CONTROL | component 19 TRANSPORT | Qty 1.0
# parent: 72 QUADCOPTER | component 19 TRANSPORT | Qty 2.0
# parent: 74 FLIGHT-COMPUTER | component 58 ON-BOARD-COMPUTER | Qty 2.0
# parent: 84 COCKPIT | component 9 DISPLAYS | Qty 8.0
# parent: 91 ATTITUDE-CONTROL | component 21 BATTERIES | Qty 5.0
# parent: 72 QUADCOPTER | component 21 BATTERIES | Qty 1.0
# parent: 84 COCKPIT | component 94 CAR-INTERIOR | Qty 1.0
# parent: 91 ATTITUDE-CONTROL | component 57 ELECTRIC-MOTOR | Qty 3.0
# parent: 72 QUADCOPTER | component 59 ELECTRONIC-COMPONENTS | Qty 3.0
# parent: 72 QUADCOPTER | component 18 PLASTIC | Qty 2.0
# parent: 70 STEEL-BEAMS | component 20 STEEL | Qty 1.0
# parent: 40 PLANKS | component 50 WOOD | Qty 0.5
# parent: 62 WINDOWS | component 28 ALUMINIUM | Qty 2.0
# parent: 38 TOOLS | component 20 STEEL | Qty 0.5
# parent: 70 STEEL-BEAMS | component 19 TRANSPORT | Qty 5.0
# parent: 40 PLANKS | component 19 TRANSPORT | Qty 1.0
# parent: 62 WINDOWS | component 19 TRANSPORT | Qty 1.0
# parent: 38 TOOLS | component 19 TRANSPORT | Qty 1.0
# parent: 70 STEEL-BEAMS | component 5 POWER | Qty 4.0
# parent: 62 WINDOWS | component 71 GLASS | Qty 1.0
# parent: 38 TOOLS | component 40 PLANKS | Qty 0.5
# parent: 38 TOOLS | component 59 ELECTRONIC-COMPONENTS | Qty 1.0
# parent: 38 TOOLS | component 21 BATTERIES | Qty 1.0
# parent: 13 CONSTRUCTION-UNITS | component 80 BULLDOZER | Qty 0.125
# parent: 13 CONSTRUCTION-UNITS | component 26 DIESEL | Qty 5.0
# parent: 13 CONSTRUCTION-UNITS | component 62 WINDOWS | Qty 4.0
# parent: 13 CONSTRUCTION-UNITS | component 70 STEEL-BEAMS | Qty 8.0
# parent: 13 CONSTRUCTION-UNITS | component 38 TOOLS | Qty 4.0

# %%
test = session.query(compReltn).filter_by(parent_item_id=13).all()
for i in test:
    print(i.comp_item_id)
# Out:
# 80
# 26
# 62
# 70
# 38

# %%
# clear table
session.query(compReltn).delete()
# Out:
# 48

# %%
session.commit()
